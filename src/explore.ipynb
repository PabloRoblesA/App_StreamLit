# %% [markdown]
# # Explore here

# %%
#pip install xlrd
import pandas as pd
import xlrd

df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/4923045/8288208/pokemon_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240530%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240530T211005Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
df.to_csv('../data/raw/pokemon_data_raw.csv', index=False)
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 #pip install xlrd
#       2 import pandas as pd
# ----> 3 import xlrd
#       5 df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/4923045/8288208/pokemon_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240530%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240530T211005Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
#       6 df.to_csv('../data/raw/pokemon_data_raw.csv', index=False)
#
# ModuleNotFoundError: No module named 'xlrd'

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dexnum           1025 non-null   int64
#  1   name             1025 non-null   object
#  2   generation       1025 non-null   int64
#  3   type1            1025 non-null   object
#  4   type2            526 non-null    object
#  5   species          1025 non-null   object
#  6   height           1025 non-null   float64
#  7   weight           1025 non-null   float64
#  8   ability1         1025 non-null   object
#  9   ability2         858 non-null    object
#  10  hidden_ability   530 non-null    object
#  11  hp               1025 non-null   int64
#  12  attack           1025 non-null   int64
#  13  defense          1025 non-null   int64
#  14  sp_atk           1025 non-null   int64
#  15  sp_def           1025 non-null   int64
#  16  speed            1025 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['dexnum', 'name', 'generation', 'type1', 'type2', 'species', 'height',
#        'weight', 'ability1', 'ability2', 'hidden_ability', 'hp', 'attack',
#        'defense', 'sp_atk', 'sp_def', 'speed', 'total', 'ev_yield',
#        'catch_rate', 'base_friendship', 'base_exp', 'growth_rate',
#        'egg_group1', 'egg_group2', 'percent_male', 'percent_female',
#        'egg_cycles', 'special_group'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#Usar la suma de las caracteristicas ('total') para predecir la tasa de crecimiento ('growth_rate')
caracteristicas = df[['total']]
pokeresultado = df['growth_rate']

X_train, X_test, y_train, y_test = train_test_split(caracteristicas, pokeresultado, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train)
X_test_scaler = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

modelo_regrlog = LogisticRegression(max_iter=1000)

modelo_regrlog.fit(X_train_scaler, y_train)

y_pred = modelo_regrlog.predict(X_test_scaler)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.4975609756097561

# %%
from sklearn.tree import DecisionTreeClassifier

modelo_arbol = DecisionTreeClassifier(random_state=42)

modelo_arbol.fit(X_train, y_train)

y_pred = modelo_arbol.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.5024390243902439

# %%
from sklearn.ensemble import RandomForestClassifier

modelo_bosque = RandomForestClassifier(n_estimators=100, random_state=42)

modelo_bosque.fit(X_train, y_train)

y_pred = modelo_bosque.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
#Seleccionado para mejorar hiperparametros
# Out:
# Accuracy: 0.526829268292683

# %%
from sklearn.ensemble import GradientBoostingClassifier

modelo_boosting = GradientBoostingClassifier(random_state=42)

modelo_boosting.fit(X_train, y_train)

y_pred = modelo_boosting.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.4975609756097561

# %%
from sklearn.naive_bayes import GaussianNB

modelo_naive = GaussianNB()

modelo_naive.fit(X_train, y_train)

y_pred = modelo_naive.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.5121951219512195

# %%
from sklearn.neighbors import KNeighborsClassifier

modelo_vecinos = KNeighborsClassifier(n_neighbors=5)

modelo_vecinos.fit(X_train, y_train)

y_pred = modelo_vecinos.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.4878048780487805

# %%
#Optimizacion de hiperparametros de Random Forest
from sklearn.model_selection import GridSearchCV

hyperparametros= {
    'n_estimators':[50, 60, 75, 80, 90, 100],
    'criterion':['gini', 'entropy', 'log_loss'],
    'bootstrap':[True,False],
    'max_depth':[None,3,5, 7, 8, 10],
}
grid= GridSearchCV(modelo_bosque,hyperparametros,scoring='accuracy',cv=5)
grid
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 3, 5, 7, 8, 10],
#                          'n_estimators': [50, 60, 75, 80, 90, 100]},
#              scoring='accuracy')

# %%
grid.fit(X_train,y_train)
print(f'Mejores parametros: {grid.best_params_}')
# Out:
# Mejores parametros: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 7, 'n_estimators': 60}

# %%
modelo_mejorado = RandomForestClassifier(bootstrap=True,criterion='gini',max_depth=7,n_estimators=60,random_state=42)
modelo_mejorado.fit(X_train,y_train)
accuracy_score(y_test, y_pred)
#Grid empeora accuracy del modelo
# Out:
# 0.4878048780487805

# %%
#Guardado del modelo Random Forest ('modelo_bosque')
from pickle import dump

dump(modelo_bosque, open("../models/random_forest_classifier_default_42.sav", "wb"))

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0
